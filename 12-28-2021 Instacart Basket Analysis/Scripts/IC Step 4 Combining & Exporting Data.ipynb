# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Importing csvs

# %%
# Import modified orders.csv

path = r'/Users/matthewabrams/Desktop/12-28-2021 Instacart Basket Analysis'
df_orders = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'orders_clean_csv'))
df_orders.drop(columns = ('Unnamed: 0'), inplace = True)
df_orders
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 0         2539329        1             1                  2
# 1         2398795        1             2                  3
# 2          473747        1             3                  3
# 3         2254736        1             4                  4
# 4          431534        1             5                  4
# ...           ...      ...           ...                ...
# 3421078   2266710   206209            10                  5
# 3421079   1854736   206209            11                  4
# 3421080    626363   206209            12                  1
# 3421081   2977660   206209            13                  1
# 3421082    272231   206209            14                  6
#
#          order_hour_of_day  days_since_prior_order  first_order
# 0                        8                     NaN         True
# 1                        7                    15.0        False
# 2                       12                    21.0        False
# 3                        7                    29.0        False
# 4                       15                    28.0        False
# ...                    ...                     ...          ...
# 3421078                 18                    29.0        False
# 3421079                 10                    30.0        False
# 3421080                 12                    18.0        False
# 3421081                 12                     7.0        False
# 3421082                 14                    30.0        False
#
# [3421083 rows x 7 columns]

# %%
# Import modified products.csv
df_products = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'products_clean_csv'))
df_products.drop(columns = ('Unnamed: 0'), inplace = True)
df_products
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
# 49685       49686                                   Artisan Baguette
# 49686       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49687       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices  unknown_product_name
# 0            61             19     5.8                 False
# 1           104             13     9.3                 False
# 2            94              7     4.5                 False
# 3            38              1    10.5                 False
# 4             5             13     4.3                 False
# ...         ...            ...     ...                   ...
# 49683       124              5     5.3                 False
# 49684        42              1     3.1                 False
# 49685       112              3     7.8                 False
# 49686        41              8     4.7                 False
# 49687        73             11    13.5                 False
#
# [49688 rows x 6 columns]

# %%
# Import prior_orders_products.csv

df_order_products = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'order_products__prior.csv'))
df_order_products
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %% [markdown]
# # 3. Checking for data consistency of df_order_products before merging

# %%
df_order_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB

# %%
# No null values

df_order_products.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
# No duplicates

df_order_products[df_order_products.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %% [markdown]
# # 4. Merging Data Sets

# %%
# Merging orders csv with orders_product_prior csv, labeled as orders_products_combined

orders_products_combined = df_orders.merge(df_order_products, on = 'order_id')
orders_products_combined
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2539329        1             1                  2
# 2          2539329        1             1                  2
# 3          2539329        1             1                  2
# 4          2539329        1             1                  2
# ...            ...      ...           ...                ...
# 32434484   2977660   206209            13                  1
# 32434485   2977660   206209            13                  1
# 32434486   2977660   206209            13                  1
# 32434487   2977660   206209            13                  1
# 32434488   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 0                         8                     NaN         True         196
# 1                         8                     NaN         True       14084
# 2                         8                     NaN         True       12427
# 3                         8                     NaN         True       26088
# 4                         8                     NaN         True       26405
# ...                     ...                     ...          ...         ...
# 32434484                 12                     7.0        False       14197
# 32434485                 12                     7.0        False       38730
# 32434486                 12                     7.0        False       31477
# 32434487                 12                     7.0        False        6567
# 32434488                 12                     7.0        False       22920
#
#           add_to_cart_order  reordered
# 0                         1          0
# 1                         2          0
# 2                         3          0
# 3                         4          0
# 4                         5          0
# ...                     ...        ...
# 32434484                  5          1
# 32434485                  6          0
# 32434486                  7          0
# 32434487                  8          0
# 32434488                  9          0
#
# [32434489 rows x 10 columns]

# %%
# To merge both orders_product_combined and product dataframes, use the product_id as a common identifier. Named this combined data frame df_merged
# Used inner join because we want to only focus on the customers who orders online 

df_merged = orders_products_combined.merge(df_products, on = 'product_id', indicator = True)
df_merged
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32433025   1320836   202557            17                  2
# 32433026     31526   202557            18                  5
# 32433027    758936   203436             1                  2
# 32433028   2745165   203436             2                  3
# 32433029   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 0                         8                     NaN         True         196
# 1                         7                    15.0        False         196
# 2                        12                    21.0        False         196
# 3                         7                    29.0        False         196
# 4                        15                    28.0        False         196
# ...                     ...                     ...          ...         ...
# 32433025                 15                     1.0        False       43553
# 32433026                 11                     3.0        False       43553
# 32433027                  7                     NaN         True       42338
# 32433028                  5                    15.0        False       42338
# 32433029                 14                     NaN         True       28818
#
#           add_to_cart_order  reordered                   product_name  \
# 0                         1          0                           Soda
# 1                         1          1                           Soda
# 2                         1          1                           Soda
# 3                         1          1                           Soda
# 4                         1          1                           Soda
# ...                     ...        ...                            ...
# 32433025                  2          1            Orange Energy Shots
# 32433026                  2          1            Orange Energy Shots
# 32433027                  4          0          Zucchini Chips, Pesto
# 32433028                 16          1          Zucchini Chips, Pesto
# 32433029                  8          0  Hot Oatmeal Multigrain Raisin
#
#           aisle_id  department_id  prices  unknown_product_name _merge
# 0               77              7     9.0                 False   both
# 1               77              7     9.0                 False   both
# 2               77              7     9.0                 False   both
# 3               77              7     9.0                 False   both
# 4               77              7     9.0                 False   both
# ...            ...            ...     ...                   ...    ...
# 32433025        64              7     3.7                 False   both
# 32433026        64              7     3.7                 False   both
# 32433027        50             19     6.9                 False   both
# 32433028        50             19     6.9                 False   both
# 32433029       130             14    10.3                 False   both
#
# [32433030 rows x 16 columns]

# %%
df_merged.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))
